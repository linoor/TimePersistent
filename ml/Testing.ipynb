# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
pd.options.mode.chained_assignment = None
from sklearn.externals import joblib

from datetime import datetime

# %%
rf = joblib.load('voyages_model1')

# %%
start_date = datetime(2016, 4, 18, 7, 0)
end_date = datetime(2016, 4, 18, 15, 0)

daterange = pd.date_range(start_date, end_date, freq='5min')

print([date.value // 10**11 for date in daterange])
# Out:
# [14609628, 14609631, 14609634, 14609637, 14609640, 14609643, 14609646, 14609649, 14609652, 14609655, 14609658, 14609661, 14609664, 14609667, 14609670, 14609673, 14609676, 14609679, 14609682, 14609685, 14609688, 14609691, 14609694, 14609697, 14609700, 14609703, 14609706, 14609709, 14609712, 14609715, 14609718, 14609721, 14609724, 14609727, 14609730, 14609733, 14609736, 14609739, 14609742, 14609745, 14609748, 14609751, 14609754, 14609757, 14609760, 14609763, 14609766, 14609769, 14609772, 14609775, 14609778, 14609781, 14609784, 14609787, 14609790, 14609793, 14609796, 14609799, 14609802, 14609805, 14609808, 14609811, 14609814, 14609817, 14609820, 14609823, 14609826, 14609829, 14609832, 14609835, 14609838, 14609841, 14609844, 14609847, 14609850, 14609853, 14609856, 14609859, 14609862, 14609865, 14609868, 14609871, 14609874, 14609877, 14609880, 14609883, 14609886, 14609889, 14609892, 14609895, 14609898, 14609901, 14609904, 14609907, 14609910, 14609913, 14609916]

# %%
pred = rf.predict([1461065774, 2])
print(pred)
# Out:
# [1]
# C:\Users\mpomaran\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
dates = [date.value // 10**9 for date in daterange]
print(dates)
preds = [rf.predict([date, 3]) for date in dates]
# Out:
# [1460962800, 1460963100, 1460963400, 1460963700, 1460964000, 1460964300, 1460964600, 1460964900, 1460965200, 1460965500, 1460965800, 1460966100, 1460966400, 1460966700, 1460967000, 1460967300, 1460967600, 1460967900, 1460968200, 1460968500, 1460968800, 1460969100, 1460969400, 1460969700, 1460970000, 1460970300, 1460970600, 1460970900, 1460971200, 1460971500, 1460971800, 1460972100, 1460972400, 1460972700, 1460973000, 1460973300, 1460973600, 1460973900, 1460974200, 1460974500, 1460974800, 1460975100, 1460975400, 1460975700, 1460976000, 1460976300, 1460976600, 1460976900, 1460977200, 1460977500, 1460977800, 1460978100, 1460978400, 1460978700, 1460979000, 1460979300, 1460979600, 1460979900, 1460980200, 1460980500, 1460980800, 1460981100, 1460981400, 1460981700, 1460982000, 1460982300, 1460982600, 1460982900, 1460983200, 1460983500, 1460983800, 1460984100, 1460984400, 1460984700, 1460985000, 1460985300, 1460985600, 1460985900, 1460986200, 1460986500, 1460986800, 1460987100, 1460987400, 1
# ...

# %%
for pred in preds:
    print(pred)
# Out:
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
